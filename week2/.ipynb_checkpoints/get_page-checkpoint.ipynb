# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://newyork.craigslist.org/que/zip/d/large-dog-crate/6477702014.html"

html = requests.get(url).text

soup = BeautifulSoup(html, 'html.parser')

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head>
# <title>Large dog crate. - free stuff</title>
#     	<link rel="canonical" href="https://newyork.craigslist.org/que/zip/d/large-dog-crate/6477702014.html">
# 	<meta name="description" content="Black wire dog crate, houses a 100-pound mastiff quite comfortably. It's a bit of a pain to unfold, but h**kin' sturdy.">
# 	<meta name="robots" content="noarchive,nofollow,unavailable_after: 05-Feb-18 19:55:34 EST">
# 	<meta name="twitter:card" content="preview">
# 	<meta property="og:description" content="Black wire dog crate, houses a 100-pound mastiff quite comfortably. It's a bit of a pain to unfold, but h**kin' sturdy.">
# 	<meta property="og:image" content="https://images.craigslist.org/00F0F_7KEBxuNXMc5_600x450.jpg">
# 	<meta property="og:site_name" content="craigslist">
# 	<meta property="og:title" content="Large dog crate.">
# 	<meta property="og:type" content="article">
# ...

# %%
titles = soup.select('.user')
print(titles)
# Out:
# [<li class="user post">
# <a href="https://post.craigslist.org/c/nyc">post</a>
# </li>, <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>, <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number"></span><span class="fav-label"> favorites</span></a>
# </div>
# </li>, <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="/que/zip/6477702014.html"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value="Large dog crate."/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count"></span>
# ...

# %%
for title in titles:
    print(title.text.strip().encode('utf-8'))
# Out:
# b'post'
# b'account'
# b'favorites'
# b'hidden'
